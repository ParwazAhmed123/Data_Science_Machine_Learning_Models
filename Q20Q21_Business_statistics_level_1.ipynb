# %%
from scipy import stats
from scipy.stats import norm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.dpi'] = 150
plt.rcParams['figure.figsize'] = (10,5)
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\ahmed\Downloads\Cars.csv")
df
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
df.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
mean = df['MPG'].mean()
mean
# Out:
# 34.42207572802469

# %%
std = df['MPG'].std()
std
# Out:
# 9.131444731795982

# %%
z_scores = stats.zscore(df['MPG'])
z_scores
# Out:
# 0     2.124387
# 1     1.718071
# 2     1.718071
# 3     1.242355
# 4     1.772157
#         ...
# 76    0.273052
# 77   -1.677614
# 78   -0.046510
# 79   -1.607548
# 80   -2.459620
# Name: MPG, Length: 81, dtype: float64

# %%
mpg = 38
z=(mpg-mean)/std
z
# Out:
# 0.39182455537587235

# %%
p_value = norm.cdf(z)
p_value
# Out:
# 0.6524060748417286

# %%
#For mpg > 38
p=1-p_value
p
# Out:
# 0.34759392515827137

# %%
sns.distplot(z_scores, hist = False)
plt.axvline(x = z, linestyle = '--', color = 'red')

# %%
stats.norm.cdf(38,mean,std)
# Out:
# 0.6524060748417286

# %%
#For P(MPG>38)
1-stats.norm.cdf(38,mean,std)
# Out:
# 0.34759392515827137

# %%
#For P(MPG<40)
stats.norm.cdf(40,mean,std)
# Out:
# 0.7293498762151609

# %%
#For P(20<MPG<50)
stats.norm.cdf(50,mean,std)-stats.norm.cdf(20,mean,std)
# Out:
# 0.8988689169682047

# %%
sns.distplot(df['MPG'])
# Out:
# <Axes: xlabel='MPG', ylabel='Density'>

# %%
data = pd.read_csv(r"C:\Users\ahmed\Downloads\wc-at.csv")
data
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
data.describe()
# Out:
#             Waist          AT
# count  109.000000  109.000000
# mean    91.901835  101.894037
# std     13.559116   57.294763
# min     63.500000   11.440000
# 25%     80.000000   50.880000
# 50%     90.800000   96.540000
# 75%    104.000000  137.000000
# max    121.000000  253.000000

# %%
sns.distplot(data['Waist'], hist = False)
# Out:
# <Axes: xlabel='Waist', ylabel='Density'>

# %%
z_scores = stats.zscore(data['Waist'])
z_scores
# Out:
# 0     -1.270810
# 1     -1.430107
# 2     -0.748463
# 3     -0.589166
# 4     -1.278219
#          ...
# 104    0.607417
# 105    0.103593
# 106    0.733373
# 107    1.185332
# 108    1.229788
# Name: Waist, Length: 109, dtype: float64

# %%
sns.distplot(z_scores, hist = False)
# Out:
# <Axes: xlabel='Waist', ylabel='Density'>

# %%
sns.distplot(data['AT'], hist = False)
# Out:
# <Axes: xlabel='AT', ylabel='Density'>

# %%
z_scores = stats.zscore(data['AT'])
z_scores
# Out:
# 0     -1.335652
# 1     -1.332671
# 2     -1.039675
# 3     -1.036168
# 4     -1.263411
#          ...
# 104    0.387611
# 105   -0.696004
# 106    0.545419
# 107    1.860485
# 108    1.860485
# Name: AT, Length: 109, dtype: float64

# %%
sns.distplot(z_scores, hist = False)
# Out:
# <Axes: xlabel='AT', ylabel='Density'>
