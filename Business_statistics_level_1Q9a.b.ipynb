# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.dpi'] = 150
plt.rcParams['figure.figsize'] = (10,5)
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\ahmed\Downloads\Q9_a.csv', index_col = 0)
df
# Out:
#        speed  dist
# Index
# 1          4     2
# 2          4    10
# 3          7     4
# 4          7    22
# 5          8    16
# 6          9    10
# 7         10    18
# 8         10    26
# 9         10    34
# 10        11    17
# 11        11    28
# 12        12    14
# 13        12    20
# 14        12    24
# 15        12    28
# 16        13    26
# 17        13    34
# 18        13    34
# 19        13    46
# 20        14    26
# 21        14    36
# 22        14    60
# 23        14    80
# 24        15    20
# 25        15    26
# 26        15    54
# 27        16    32
# 28        16    40
# 29        17    32
# 30        17    40
# 31        17    50
# 32        18    42
# 33        18    56
# 34        18    76
# 35        18    84
# 36        19    36
# 37        19    46
# 38        19    68
# 39        20    32
# 40        20    48
# 41        20    52
# 42        20    56
# 43        20    64
# 44        22    66
# 45        23    54
# 46        24    70
# ...

# %%
df.describe()
# Out:
#            speed        dist
# count  50.000000   50.000000
# mean   15.400000   42.980000
# std     5.287644   25.769377
# min     4.000000    2.000000
# 25%    12.000000   26.000000
# 50%    15.000000   36.000000
# 75%    19.000000   56.000000
# max    25.000000  120.000000

# %%
df.skew()
# Out:
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %%
df.kurtosis()
# Out:
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %%
sns.distplot(df['speed'])
# Out:
# <Axes: xlabel='speed', ylabel='Density'>

# %%
sns.distplot(df['dist'])
# Out:
# <Axes: xlabel='dist', ylabel='Density'>

# %%
data = pd.read_csv(r'C:\Users\ahmed\Downloads\Q9_b.csv', index_col = 0)
data
# Out:
#             SP         WT
# 1   104.185353  28.762059
# 2   105.461264  30.466833
# 3   105.461264  30.193597
# 4   113.461264  30.632114
# 5   104.461264  29.889149
# ..         ...        ...
# 77  169.598513  16.132947
# 78  150.576579  37.923113
# 79  151.598513  15.769625
# 80  167.944460  39.423099
# 81  139.840817  34.948615
#
# [81 rows x 2 columns]

# %%
data.describe()
# Out:
#                SP         WT
# count   81.000000  81.000000
# mean   121.540272  32.412577
# std     14.181432   7.492813
# min     99.564907  15.712859
# 25%    113.829145  29.591768
# 50%    118.208698  32.734518
# 75%    126.404312  37.392524
# max    169.598513  52.997752

# %%
data.skew()
# Out:
# SP    1.611450
# WT   -0.614753
# dtype: float64

# %%
data.kurtosis()
# Out:
# SP    2.977329
# WT    0.950291
# dtype: float64

# %%
sns.distplot(data['SP'])
# Out:
# <Axes: xlabel='SP', ylabel='Density'>

# %%
sns.distplot(data['WT'])
# Out:
# <Axes: xlabel='WT', ylabel='Density'>

# %%
plt.boxplot(data)
plt.show()
